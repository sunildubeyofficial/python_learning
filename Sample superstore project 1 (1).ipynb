# %% [markdown]
# # Sample project (Superstore) Day-1

# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('S:\Python')
df=pd.read_excel('Superstore.xls')

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index              128
# Row ID           79952
# Order ID         79952
# Order Date       79952
# Ship Date        79952
# Ship Mode        79952
# Customer ID      79952
# Customer Name    79952
# Segment          79952
# Country          79952
# City             79952
# State            79952
# Postal Code      79952
# Region           79952
# Product ID       79952
# Category         79952
# Sub-Category     79952
# Product Name     79952
# Sales            79952
# Quantity         79952
# Discount         79952
# Profit           79952
# dtype: int64

# %% [markdown]
# # Replace space with "_"

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Adding new column "Status"

# %%
df['Status']= np.where(
    df['Profit'] >=0,'Positive',np.where(
    df['Profit']<0,'Nigative',-1))

# %%
df.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product_ID         Category Sub-Category  \
# ...

# %%
df['Status'].head(10)
# Out:
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Nigative
# 4    Positive
# 5    Positive
# 6    Positive
# 7    Positive
# 8    Positive
# 9    Positive
# Name: Status, dtype: object

# %% [markdown]
# # Day-2 (Sample project task)

# %% [markdown]
# ## Task 1 (creating 3 data for each criteria)

# %%
df_positive=df.loc[df.Status=='Positive']
df_positive.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      Customer_Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...   West
#
#         Product_ID         Category Sub-Category  \
# ...

# %%
df_nigative=df.loc[df.Status=='Nigative']
df_nigative.head()
# Out:
#     Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 3        4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 14      15  US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
# 15      16  US-2015-118983 2015-11-22 2015-11-26  Standard Class    HP-14815
# 23      24  US-2017-156909 2017-07-16 2017-07-18    Second Class    SF-20065
# 27      28  US-2015-150630 2015-09-17 2015-09-21  Standard Class    TB-21520
#
#       Customer_Name      Segment        Country             City  ...  \
# 3    Sean O'Donnell     Consumer  United States  Fort Lauderdale  ...
# 14    Harold Pawlan  Home Office  United States       Fort Worth  ...
# 15    Harold Pawlan  Home Office  United States       Fort Worth  ...
# 23  Sandra Flanagan     Consumer  United States     Philadelphia  ...
# 27  Tracy Blumstein     Consumer  United States     Philadelphia  ...
#
#      Region       Product_ID         Category Sub-Category  \
# ...

# %%
df_all=df
df_all.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product_ID         Category Sub-Category  \
# ...

# %%
df_all['dt_diff']=(df_all['Ship_Date'] - df_all['Order_Date']).dt.days
df_all['Ship_status']=np.where(df_all.dt_diff > 2,'Late', 'Ontime')
df_all.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
df_all[['Region','State','Sales','Profit']].groupby(['Region','State']).sum(['Sales','Profit'])
# Out:
#                                     Sales      Profit
# Region  State
# Central Illinois               80166.1010 -12607.8870
#         Indiana                53555.3600  18382.9363
#         Iowa                    4579.7600   1183.8119
#         Kansas                  2914.3100    836.4435
#         Michigan               76269.6140  24463.1876
#         Minnesota              29863.1500  10823.1874
#         Missouri               22205.1500   6436.2105
#         Nebraska                7464.9300   2037.0942
#         North Dakota             919.9100    230.1497
#         Oklahoma               19683.3900   4853.9560
#         South Dakota            1315.5600    394.8283
#         Texas                 170188.0458 -25729.3563
#         Wisconsin              32114.6100   8401.8004
# East    Connecticut            13384.3570   3511.4918
#         Delaware               27451.0690   9977.3748
#         District of Columbia    2865.0200   1059.5893
# ...

# %%
df_all[['Region','State','City','Sales','Profit']].groupby(['Region','State','City']).sum(['Sales','Profit'])
# Out:
#                                            Sales      Profit
# Region  State      City
# Central Illinois   Arlington Heights      14.112      1.2348
#                    Aurora               7572.968  -1894.7196
#                    Bloomington           963.940   -432.1283
#                    Bolingbrook           218.308     -4.6610
#                    Buffalo Grove         831.399    -89.6478
# ...                                          ...         ...
# West    Washington Renton               1242.632    185.4324
#                    Seattle            119540.742  29156.0967
#                    Spokane              2027.918    172.2261
#                    Vancouver             686.836     75.4546
#         Wyoming    Cheyenne             1603.136    100.1960
#
# [604 rows x 2 columns]

# %%
df_all[['Category','Sub-Category','Sales','Profit']].groupby(['Category','Sub-Category']).sum(['Sales','Profit'])
# Out:
#                                     Sales      Profit
# Category        Sub-Category
# Furniture       Bookcases     114879.9963  -3472.5560
#                 Chairs        328449.1030  26590.1663
#                 Furnishings    91705.1640  13059.1436
#                 Tables        206965.5320 -17725.4811
# Office Supplies Appliances    107532.1610  18138.0054
#                 Art            27118.7920   6527.7870
#                 Binders       203412.7330  30221.7633
#                 Envelopes      16476.4020   6964.1767
#                 Fasteners       3024.2800    949.5182
#                 Labels         12486.3120   5546.2540
#                 Paper          78479.2060  34053.5693
#                 Storage       223843.6080  21278.8264
#                 Supplies       46673.5380  -1189.0995
# Technology      Accessories   167380.3180  41936.6357
#                 Copiers       149528.0300  55617.8249
#                 Machines      189238.6310   3384.7569
# ...

# %%
pd.pivot_table(df, index=['Category','Sub-Category'], values=['Sales','Profit'])
# Out:
#                                   Profit        Sales
# Category        Sub-Category
# Furniture       Bookcases     -15.230509   503.859633
#                 Chairs         43.095894   532.332420
#                 Furnishings    13.645918    95.825668
#                 Tables        -55.565771   648.794771
# Office Supplies Appliances     38.922758   230.755710
#                 Art             8.200737    34.068834
#                 Binders        19.843574   133.560560
#                 Envelopes      27.418019    64.867724
#                 Fasteners       4.375660    13.936774
#                 Labels         15.236962    34.303055
#                 Paper          24.856620    57.284092
#                 Storage        25.152277   264.590553
#                 Supplies       -6.258418   245.650200
# Technology      Accessories    54.111788   215.974604
#                 Copiers       817.909190  2198.941618
#                 Machines       29.432669  1645.553313
# ...

# %%
# Out:
#                       Sales
# Category
# Furniture        349.834887
# Office Supplies  119.324101
# Technology       452.709276
